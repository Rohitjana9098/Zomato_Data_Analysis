# %% [markdown]
# **zomato data analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Zomato data .csv')

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df['rate'] = df['rate'].str.split('/').str[0].astype(float)

# %%
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x = df['listed_in(type)'],
              palette=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']);
plt.xlabel("Type of resturent");
# Out:
# /tmp/ipython-input-2885322762.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['listed_in(type)'],

# %%
votes_by_type = df.groupby('listed_in(type)')['votes'].sum()

plt.figure(figsize=(8,5))
plt.plot(votes_by_type.index, votes_by_type.values, marker='o')
plt.xlabel("Type of restaurant")
plt.ylabel("Total votes")
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(df["rate"],bins=3, color='skyblue')
plt.title("Distribution of Ratings")
plt.show()

# %%
Couple_data = df["approx_cost(for two people)"]

sweet_colors = ["#FFD1DC", "#CDE7FF", "#D5F5E3", "#FFF3B0", "#E8DAEF"]
sns.countplot(x=Couple_data, palette=sweet_colors)
# Out:
# /tmp/ipython-input-3133393515.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=Couple_data, palette=sweet_colors)
# /tmp/ipython-input-3133393515.py:4: UserWarning:
# The palette list has fewer values (5) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x=Couple_data, palette=sweet_colors)
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    x="online_order",
    data=df,
    palette=["#FFD1DC", "#CDE7FF"],
    edgecolor="black",
    linewidth=1
)

plt.title("Restaurants Offering Online Order")
plt.xlabel("Online Order")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-743772703.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
pivot_table = df.pivot_table(index = 'listed_in(type)', columns = 'online_order' , aggfunc = 'size' , fill_value = 0)
sns.heatmap(pivot_table,annot = True , cmap = "cividis",fmt = 'd');
plt.title("HeatMap")
plt.xlabel("Online order")
plt.ylabel("Listed in (Type)")
plt.show()
